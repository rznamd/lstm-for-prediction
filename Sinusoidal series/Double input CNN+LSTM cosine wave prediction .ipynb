# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from tensorflow import keras
from tensorflow.keras.optimizers import Adam
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.models import Sequential, Model
from keras.layers import Input, LSTM, Dense, Flatten, TimeDistributed, Conv1D, MaxPooling1D, Concatenate, Add
# Out:
# Using TensorFlow backend.

# %%
# Building cosine wave dataset

x = 0.1*np.arange(1000)
data = np.cos(x)

# %%
# Ploting cosine wave with generated dataset 

plt.style.use('ggplot')

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.spines['bottom'].set_position('center')
ax.spines['bottom'].set_color('black')
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')

ax.set_xlim(0,100,auto=True)

plt.plot(x,data, 'r')

plt.show()

# %%
# Scaling down the raw data with StandardScaler()

scaler_01 = StandardScaler()
data_scaled = scaler_01.fit_transform(data.reshape(-1,1))
scaler_02 = StandardScaler()
x_scaled = scaler_02.fit_transform(x.reshape(-1,1))

# %%
data_scaled = data_scaled.flatten()
x_scaled = x_scaled.flatten()

# %%
# Splitting the scaled data into training dataset

training_dataset = data_scaled[:-150]
x_training_dataset = x_scaled[:-150]

# %%
# Splitting the scaled data into test dataset, this dataset won't be used in LSTM model training

test_dataset = data_scaled[-(150+10):]
x_test_dataset = x_scaled[-(150+10):]

# %%
# Preparing the training dataset for LSTM input1 

T = 20
X = []
Y = []

for t in range(len(training_dataset)-T):
  x = training_dataset[t:t+T]
  X.append(x)
  y = training_dataset[t+T]
  Y.append(y)
X = np.array(X).reshape(-1, T, 1)
Y = np.array(Y)
N = len(X)
print("X.Shape:",X.shape, "Y.Shape:", Y.shape)
# Out:
# X.Shape: (830, 20, 1) Y.Shape: (830,)

# %%
# Preparing the training dataset for LSTM input2 

T = 20
XX = []

for t in range(len(x_training_dataset)-T):
  x = x_training_dataset[t:t+T]
  XX.append(x)
  y = x_training_dataset[t+T]
XX = np.array(XX).reshape(-1, T, 1)
print("XX.Shape:",XX.shape)
# Out:
# XX.Shape: (830, 20, 1)

# %%
# Splitting training dataset for input1 again into x_train, x_test, y_train, y_test

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)
print("x_train.shape:",x_train.shape, "x_test.shape:",x_test.shape, "y_train.shape:",y_train.shape, "y_test.shape:",y_test.shape)
# Out:
# x_train.shape: (664, 20, 1) x_test.shape: (166, 20, 1) y_train.shape: (664,) y_test.shape: (166,)

# %%
# Splitting training dataset for input2 again into xx_train, xx_test

xx_train, xx_test = train_test_split(XX, test_size=0.2, shuffle=False)
print("xx_train.shape:",xx_train.shape, "xx_test.shape:",xx_test.shape)
# Out:
# xx_train.shape: (664, 20, 1) xx_test.shape: (166, 20, 1)

# %%
# Building Double input CNN+LSTM model

input1 = Input(shape=(20,1))
x10 = Conv1D(filters=100, kernel_size=2, activation='relu')(input1)
x11 = MaxPooling1D(pool_size=2)(x10)
x12 = Flatten()(x11)
x1 = Dense(20, activation='relu')(x12)

input2 = Input(shape=(20,1))
x2 = LSTM(30, activation='selu')(input2)


# equivalent to `added = tf.keras.layers.add([x1, x2])`

added = Concatenate(axis=-1)([x1, x2])
out = Dense(1, activation='selu')(added)
model = Model(inputs=[input1, input2], outputs=out)

model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0730 15:12:45.794177 18304 deprecation_wrapper.py:119] From C:\Users\22458147\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# W0730 15:12:45.904617 18304 deprecation.py:323] From C:\Users\22458147\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:3313: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where

# %%
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 20, 1)        0
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 19, 100)      300         input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 9, 100)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# flatten_1 (Flatten)             (None, 900)          0           max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, 20, 1)        0
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 20)           18020       flatten_1[0][0]
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   (None, 30)           3840        input_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 50)           0           dense_1[0][0]
#                                                                  lstm_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            51          concatenate_1[0][0]
# ==================================================================================================
# Total params: 22,211
# Trainable params: 22,211
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
r = model.fit([x_train.reshape(664, 20, 1), xx_train.reshape(664, 20, 1)], y_train, epochs=30, validation_data=([x_test.reshape(166, 20, 1),xx_test.reshape(166, 20, 1)], y_test))
# Out:
# W0730 15:12:50.236612 18304 deprecation_wrapper.py:119] From C:\Users\22458147\AppData\Local\Continuum\anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py:422: The name tf.global_variables is deprecated. Please use tf.compat.v1.global_variables instead.
# Train on 664 samples, validate on 166 samples
# Epoch 1/30
# 664/664 [==============================] - 2s 2ms/step - loss: 0.5557 - accuracy: 0.0000e+00 - val_loss: 0.3072 - val_accuracy: 0.0000e+00
# Epoch 2/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.1133 - accuracy: 0.0000e+00 - val_loss: 0.1068 - val_accuracy: 0.0000e+00
# Epoch 3/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0705 - accuracy: 0.0000e+00 - val_loss: 0.0558 - val_accuracy: 0.0000e+00
# Epoch 4/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0526 - accuracy: 0.0000e+00 - val_loss: 0.0543 - val_accuracy: 0.0000e+00
# Epoch 5/30
# 664/664 [==============================] - 1s 2ms/step - loss: 0.0449 - accuracy: 0.0000e+00 - val_loss: 0.0474 - val_accuracy: 0.0000e+00
# Epoch 6/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0377 - accuracy: 0.0000e+00 - val_loss: 0.0264 - val_accuracy: 0.0000e+00
# Epoch 7/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0366 - accuracy: 0.0000e+00 - val_loss: 0.0233 - val_accuracy: 0.0000e+00
# Epoch 8/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0215 - accuracy: 0.0000e+00 - val_loss: 0.0158 - val_accuracy: 0.0000e+00
# Epoch 9/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0170 - accuracy: 0.0000e+00 - val_loss: 0.0273 - val_accuracy: 0.0000e+00
# Epoch 10/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0197 - accuracy: 0.0000e+00 - val_loss: 0.0328 - val_accuracy: 0.0000e+00
# Epoch 11/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0304 - accuracy: 0.0000e+00 - val_loss: 0.0188 - val_accuracy: 0.0000e+00
# Epoch 12/30
# 664/664 [==============================] - 1s 2ms/step - loss: 0.0208 - accuracy: 0.0000e+00 - val_loss: 0.0164 - val_accuracy: 0.0000e+00
# Epoch 13/30
# 664/664 [==============================] - 1s 2ms/step - loss: 0.0143 - accuracy: 0.0000e+00 - val_loss: 0.0141 - val_accuracy: 0.0000e+00
# Epoch 14/30
# 664/664 [==============================] - 1s 2ms/step - loss: 0.0156 - accuracy: 0.0000e+00 - val_loss: 0.0228 - val_accuracy: 0.0000e+00
# Epoch 15/30
# 664/664 [==============================] - 1s 2ms/step - loss: 0.0163 - accuracy: 0.0000e+00 - val_loss: 0.0144 - val_accuracy: 0.0000e+00
# Epoch 16/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0122 - accuracy: 0.0000e+00 - val_loss: 0.0234 - val_accuracy: 0.0000e+00
# Epoch 17/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0140 - accuracy: 0.0000e+00 - val_loss: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 18/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0216 - accuracy: 0.0000e+00 - val_loss: 0.0140 - val_accuracy: 0.0000e+00
# Epoch 19/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0194 - accuracy: 0.0000e+00 - val_loss: 0.0250 - val_accuracy: 0.0000e+00
# Epoch 20/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0149 - accuracy: 0.0000e+00 - val_loss: 0.0090 - val_accuracy: 0.0000e+00
# Epoch 21/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0182 - accuracy: 0.0000e+00 - val_loss: 0.0285 - val_accuracy: 0.0000e+00
# Epoch 22/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0170 - accuracy: 0.0000e+00 - val_loss: 0.0107 - val_accuracy: 0.0000e+00
# Epoch 23/30
# 664/664 [==============================] - 1s 2ms/step - loss: 0.0114 - accuracy: 0.0000e+00 - val_loss: 0.0174 - val_accuracy: 0.0000e+00
# Epoch 24/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0116 - accuracy: 0.0000e+00 - val_loss: 0.0105 - val_accuracy: 0.0000e+00
# Epoch 25/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0159 - accuracy: 0.0000e+00 - val_loss: 0.0124 - val_accuracy: 0.0000e+00
# Epoch 26/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0141 - accuracy: 0.0000e+00 - val_loss: 0.0193 - val_accuracy: 0.0000e+00
# Epoch 27/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0143 - accuracy: 0.0000e+00 - val_loss: 0.0175 - val_accuracy: 0.0000e+00
# Epoch 28/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0165 - accuracy: 0.0000e+00 - val_loss: 0.0102 - val_accuracy: 0.0000e+00
# Epoch 29/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0107 - accuracy: 0.0000e+00 - val_loss: 0.0104 - val_accuracy: 0.0000e+00
# Epoch 30/30
# 664/664 [==============================] - 1s 1ms/step - loss: 0.0141 - accuracy: 0.0000e+00 - val_loss: 0.0178 - val_accuracy: 0.0000e+00

# %%
plt.style.use('ggplot')
plt.plot(r.history['loss'], label="Loss")
plt.plot(r.history['val_loss'], label="Val Loss")
plt.legend()
plt.show()
plt.rcParams['figure.figsize'] = 6,4

# %%
result = model.predict([x_test,xx_test])

# %%
# Plotting y_test and predicted y_test 

plt.style.use('ggplot')
plt.plot(result, c='r', label="Predicted")
plt.plot(y_test, c='b', label="Original")
plt.legend(loc ="lower right") 
plt.show()

# %%
# Splitting the scaled data into test dataset, this dataset won't be used in LSTM model training

test_dataset = data_scaled[-(150+20):]
x_test_dataset = x_scaled[-(150+20):]

# %%
# Preparing the training dataset for LSTM input 

T = 20
X_test = []
Y_test = []

for t in range(len(test_dataset)-T):
  x = test_dataset[t:t+T]
  X_test.append(x)
  y = test_dataset[t+T]
  Y_test.append(y)
X_test = np.array(X_test).reshape(-1, T, 1)
Y_test = np.array(Y_test)
print("X_test.Shape:",X_test.shape, "Y_test.Shape:", Y_test.shape)
# Out:
# X_test.Shape: (150, 20, 1) Y_test.Shape: (150,)

# %%
# Preparing the training dataset for LSTM input 

T = 20
XX_test = []

for t in range(len(x_test_dataset)-T):
  x = x_test_dataset[t:t+T]
  XX_test.append(x)
  y = x_test_dataset[t+T]
XX_test = np.array(XX_test).reshape(-1, T, 1)
print("XX_test.Shape:",XX_test.shape)
# Out:
# XX_test.Shape: (150, 20, 1)

# %%
result_01 = model.predict([X_test,XX_test])

# %%
# Plotting y_test and predicted y_test 

plt.style.use('ggplot')
plt.plot(result_01, c='r', label="Predicted")
plt.plot(Y_test, c='b', label="Original")
plt.legend(loc ="lower right") 
plt.show()

# %%
# Plotting y_train, y_test, Y_test, predicted y_test and predicted Y_test (with scaled values)


x = 0.1*np.arange(1000)
fig, ax1 = plt.subplots()


ax1.plot(x[20:-150][:664], y_train, c='purple', label='y_train')
ax1.plot(x[20:-150][664:], y_test, 'c-', label='y_test')
ax1.plot(x[850:], Y_test, 'b-', label='Y_test')
ax1.plot(x[20:-150][664:], result, 'x-', label='y_test Predicted')
ax1.plot(x[850:], result_01, 'o-', label='Y_test Predicted')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
plt.legend(loc='lower left')

plt.rcParams['figure.figsize'] = 12,7
plt.show()

# %%
# Plotting y_train, predicted y_test and predicted Y_test (with original values)


fig, ax1 = plt.subplots()
ax1.plot(x[20:-150][:664], scaler_01.inverse_transform(y_train.reshape(-1,1)).flatten(), c='purple', label='y_train')
ax1.plot(x[20:-150][664:], scaler_01.inverse_transform(y_test.reshape(-1,1)).flatten(), 'c-', label='y_test')
ax1.plot(x[850:], scaler_01.inverse_transform(Y_test.reshape(-1,1)).flatten(), 'b-', label='Y_test')
ax1.plot(x[20:-150][664:], scaler_01.inverse_transform(result.reshape(-1,1)).flatten(), 'x-', label='y_test Predicted')
ax1.plot(x[850:], scaler_01.inverse_transform(result_01.reshape(-1,1)).flatten(), 'o-', label='Y_test Predicted')
ax1.xaxis.set_ticks_position('bottom')
ax1.yaxis.set_ticks_position('left')
plt.legend(loc='lower left')
plt.show()
plt.rcParams['figure.figsize'] = 12,7
